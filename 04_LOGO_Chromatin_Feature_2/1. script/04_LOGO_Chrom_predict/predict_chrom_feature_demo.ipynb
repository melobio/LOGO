# %%
import os
import h5py
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, roc_curve, auc, roc_auc_score

# %% [markdown]
# ## get chrom feature

# %%
import os
os.chdir("/alldata/LChuang_data/workspace/Project/GeneBERT/BGI-Gene_new/examples/vcf-predict")   #to workspace

# %%
# !bash run_GeneBert_919_2002_3357_3540.sh /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf 2
# Out:
# Using TensorFlow backend.
# 2021-04-29 21:59:08.042831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-04-29 21:59:08.145928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 21:59:08.146283: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 21:59:08.148000: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 21:59:08.149380: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 21:59:08.149658: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 21:59:08.151180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 21:59:08.152626: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 21:59:08.157153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 21:59:08.160821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# max_seq_len:  1000  word_seq_len:  200
# 2021-04-29 21:59:08.165373: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-04-29 21:59:08.172627: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2900000000 Hz
# 2021-04-29 21:59:08.176756: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558090da4ca0 executing computations on platform Host. Devices:
# 2021-04-29 21:59:08.176811: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2021-04-29 21:59:08.181252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 21:59:08.181382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 21:59:08.181419: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 21:59:08.181451: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 21:59:08.181483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 21:59:08.181514: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 21:59:08.181545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 21:59:08.181576: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 21:59:08.190233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 21:59:08.190433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 21:59:08.356295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 21:59:08.356348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 21:59:08.356363: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 21:59:08.362420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# 2021-04-29 21:59:08.365540: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55808f50c8f0 executing computations on platform CUDA. Devices:
# 2021-04-29 21:59:08.365581: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-04-29 21:59:08.372870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 21:59:08.372989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 21:59:08.373010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 21:59:08.373028: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 21:59:08.373045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 21:59:08.373063: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 21:59:08.373080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 21:59:08.373098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 21:59:08.377071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 21:59:08.377130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 21:59:08.377142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 21:59:08.377151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 21:59:08.381036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# Number of devices: 1
# WARNING:tensorflow:From /home/LChuang/.conda/envs/tf20_hhp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# x:  Tensor("Embedding-Token/embedding_lookup/Identity_1:0", shape=(None, None, 128), dtype=float32)
# s:  Tensor("Embedding-Segment/embedding_lookup/Identity_1:0", shape=(None, None, 128), dtype=float32)
# Q:  Tensor("Embedding-Mapping/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# Q:  Tensor("Transformer-FeedForward-Norm/add_1:0", shape=(None, None, 256), dtype=float32) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_1/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      [(None, None)]       0
# __________________________________________________________________________________________________
# Embedding-Token (Embedding)     (None, None, 128)    401664      Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, None, 128)    256         Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, None, 128)    0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, None, 128)    65536       Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, None, 128)    256         Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Mapping (Dense)       (None, None, 256)    33024       Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    263168      Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    0           Embedding-Mapping[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    512         Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward (FeedFo (None, None, 256)    525568      Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward-Add (Ad (None, None, 256)    0           Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[1][0]
# __________________________________________________________________________________________________
# Transformer-FeedForward-Norm (L (None, None, 256)    512         Transformer-FeedForward-Add[0][0]
#                                                                  Transformer-FeedForward-Add[1][0]
# __________________________________________________________________________________________________
# CLS-token (Lambda)              (None, 256)          0           Transformer-FeedForward-Norm[1][0
# __________________________________________________________________________________________________
# CLS-Activation (Dense)          (None, 919)          236183      CLS-token[0][0]
# ==================================================================================================
# Total params: 1,526,679
# Trainable params: 1,526,679
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2021-04-29 21:59:09.399322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 21:59:09.399484: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 21:59:09.399510: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 21:59:09.399533: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 21:59:09.399554: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 21:59:09.399573: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 21:59:09.399594: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 21:59:09.399614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 21:59:09.405061: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 21:59:09.405157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 21:59:09.405168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 21:59:09.405176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 21:59:09.409540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# Load weights:  /alldata/LChuang_data/workspace/Project/GeneBERT/BGI-Gene_new/data_deepsea_mat/deepsea_5_gram_2_layer_8_heads_256_dim_weights_128-0.982105-0.983445.hdf5
# GLOBAL_BATCH_SIZE:  128
# shuffle_size:  4000
# actg_value [1 2 3 4]
# n_gram_value:  [1.e+04 1.e+03 1.e+02 1.e+01 1.e+00]
# VCF file shape is :
#  (1408, 5)
# shift is  0
# __Fetching Seqs...__
# catch refseq length: 1100
# catch altseq length: 1100
# Number of variants with reference allele matched with reference genome:
# 1408
# Number of input variants:
# 1408
# Computing 1st file..
# __Processing REF Seqs and ALT Seqs__
# seqslist length : 1408,
# tem_encoded shape : (2816, 4, 1000)
# 2816
# data_all:  (2816, 1000)
# seqslist length : 1408,
# tem_encoded shape : (2816, 4, 1000)
# 2816
# data_all:  (2816, 1000)
# __Predicting__
# 2021-04-29 21:59:50.483061: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:50.484103: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# Q:  Tensor("Embedding-Mapping_1/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_2/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# Q:  Tensor("Transformer-FeedForward-Norm_2/add_1:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_3/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# 2021-04-29 21:59:52.292339: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# (2816, 1000)
# 22/22 [==============================] - 1s 67ms/step
#
# Predict epoch:0, y_pred_shape : (2816, 919)
# 2021-04-29 21:59:53.614816: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:53.615935: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 56ms/step
#
# Predict epoch:1, y_pred_shape : (2816, 919)
# 2021-04-29 21:59:55.122486: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:55.123787: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 52ms/step
#
# Predict epoch:2, y_pred_shape : (2816, 919)
# 2021-04-29 21:59:56.565139: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:56.566524: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 50ms/step
#
# Predict epoch:3, y_pred_shape : (2816, 919)
# 2021-04-29 21:59:57.965843: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:57.966892: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 54ms/step
#
# Predict epoch:4, y_pred_shape : (2816, 919)
# y_pred_ref shape (2816, 919)
# 2021-04-29 21:59:59.571256: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 21:59:59.572329: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 50ms/step
#
# Predict epoch:0, y_pred_shape : (2816, 919)
# 2021-04-29 22:00:01.054821: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:00:01.055787: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 49ms/step
#
# Predict epoch:1, y_pred_shape : (2816, 919)
# 2021-04-29 22:00:02.519019: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:00:02.520515: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 55ms/step
#
# Predict epoch:2, y_pred_shape : (2816, 919)
# 2021-04-29 22:00:04.173233: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:00:04.174280: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 50ms/step
#
# Predict epoch:3, y_pred_shape : (2816, 919)
# 2021-04-29 22:00:05.629289: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:00:05.630206: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 1000)
# 22/22 [==============================] - 1s 51ms/step
#
# Predict epoch:4, y_pred_shape : (2816, 919)
# y_pred_alt shape (2816, 919)
# logfoldchange and diff array shape : (1408, 1838)
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.ref.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.alt.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.logfoldchange.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.diff.csv
# compute E-values for chromatin effects V2
# /alldata/Nzhang_data/project/T2D/2.background/5.919mark_5gram/all_bdg_919_pkl.json
# pkl_filelist length is : 919
# Pkl finnished : 0
# Pkl finnished : 100
# Pkl finnished : 200
# Pkl finnished : 300
# Pkl finnished : 400
# Pkl finnished : 500
# Pkl finnished : 600
# Pkl finnished : 700
# Pkl finnished : 800
# Pkl finnished : 900
# Finished all, writing E-value output file...
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.evalue.csv
# Writing gmean of E-value output file...
# (1408, 1)
# (1408, 6)
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_919feature.out.evalue_gmean.csv
# Using TensorFlow backend.
# 2021-04-29 22:04:05.709360: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-04-29 22:04:05.808216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 22:04:05.808612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 22:04:05.810749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 22:04:05.812365: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 22:04:05.812791: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 22:04:05.816425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 22:04:05.817873: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 22:04:05.822933: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 22:04:05.827701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# max_seq_len:  2000  word_seq_len:  400
# 2021-04-29 22:04:05.834056: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2021-04-29 22:04:05.846769: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2900000000 Hz
# 2021-04-29 22:04:05.849540: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5645cf130c30 executing computations on platform Host. Devices:
# 2021-04-29 22:04:05.849576: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2021-04-29 22:04:05.851648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 22:04:05.851727: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 22:04:05.851740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 22:04:05.851752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 22:04:05.851763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 22:04:05.851774: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 22:04:05.851784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 22:04:05.851796: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 22:04:05.855411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 22:04:05.855580: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 22:04:06.004472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 22:04:06.004533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 22:04:06.004543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 22:04:06.010013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# 2021-04-29 22:04:06.012891: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5645cd928740 executing computations on platform CUDA. Devices:
# 2021-04-29 22:04:06.012920: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# 2021-04-29 22:04:06.020484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 22:04:06.020572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 22:04:06.020587: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 22:04:06.020598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 22:04:06.020610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 22:04:06.020621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 22:04:06.020632: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 22:04:06.020643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 22:04:06.024645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 22:04:06.024703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 22:04:06.024714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 22:04:06.024720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 22:04:06.028480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# Number of devices: 1
# WARNING:tensorflow:From /home/LChuang/.conda/envs/tf20_hhp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# x:  Tensor("Embedding-Token/embedding_lookup/Identity_1:0", shape=(None, None, 128), dtype=float32)
# s:  Tensor("Embedding-Segment/embedding_lookup/Identity_1:0", shape=(None, None, 128), dtype=float32)
# Q:  Tensor("Embedding-Mapping/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# Q:  Tensor("Transformer-FeedForward-Norm/add_1:0", shape=(None, None, 256), dtype=float32) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_1/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32) 8 32
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input-Token (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# Input-Segment (InputLayer)      [(None, None)]       0
# __________________________________________________________________________________________________
# Embedding-Token (Embedding)     (None, None, 128)    401664      Input-Token[0][0]
# __________________________________________________________________________________________________
# Embedding-Segment (Embedding)   (None, None, 128)    256         Input-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Token-Segment (Add)   (None, None, 128)    0           Embedding-Token[0][0]
#                                                                  Embedding-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Position (PositionEmb (None, None, 128)    131072      Embedding-Token-Segment[0][0]
# __________________________________________________________________________________________________
# Embedding-Norm (LayerNormalizat (None, None, 128)    256         Embedding-Position[0][0]
# __________________________________________________________________________________________________
# Embedding-Mapping (Dense)       (None, None, 256)    33024       Embedding-Norm[0][0]
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    263168      Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Embedding-Mapping[0][0]
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-FeedForward-Norm[0][0
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    0           Embedding-Mapping[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward-Norm[0][0
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-MultiHeadSelfAttent (None, None, 256)    512         Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward (FeedFo (None, None, 256)    525568      Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-MultiHeadSelfAttentio
# __________________________________________________________________________________________________
# Transformer-FeedForward-Add (Ad (None, None, 256)    0           Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[0][0]
#                                                                  Transformer-MultiHeadSelfAttentio
#                                                                  Transformer-FeedForward[1][0]
# __________________________________________________________________________________________________
# Transformer-FeedForward-Norm (L (None, None, 256)    512         Transformer-FeedForward-Add[0][0]
#                                                                  Transformer-FeedForward-Add[1][0]
# __________________________________________________________________________________________________
# CLS-token (Lambda)              (None, 256)          0           Transformer-FeedForward-Norm[1][0
# __________________________________________________________________________________________________
# CLS-Activation (Dense)          (None, 2002)         514514      CLS-token[0][0]
# ==================================================================================================
# Total params: 1,870,546
# Trainable params: 1,870,546
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2021-04-29 22:04:06.992957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro RTX 6000 major: 7 minor: 5 memoryClockRate(GHz): 1.77
# pciBusID: 0000:43:00.0
# 2021-04-29 22:04:06.993070: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-29 22:04:06.993090: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-04-29 22:04:06.993106: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-04-29 22:04:06.993122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-04-29 22:04:06.993137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-04-29 22:04:06.993152: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-04-29 22:04:06.993168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-04-29 22:04:06.997037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-04-29 22:04:06.997097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-29 22:04:06.997110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-04-29 22:04:06.997119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-04-29 22:04:07.001130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22848 MB memory) -> physical GPU (device: 0, name: Quadro RTX 6000, pci bus id: 0000:43:00.0, compute capability: 7.5)
# Load weights:  /alldata/LChuang_data/workspace/Project/GeneBERT/BGI-Gene_new/data_exp_mat_5_1/genebert_5_gram_2_layer_8_heads_256_dim_expecto_[mat]_weights_134-0.9633-0.9671.hdf5
# GLOBAL_BATCH_SIZE:  128
# shuffle_size:  4000
# actg_value [1 2 3 4]
# n_gram_value:  [1.e+04 1.e+03 1.e+02 1.e+01 1.e+00]
# VCF file shape is :
#  (1408, 5)
# shift is  0
# __Fetching Seqs...__
# catch refseq length: 2100
# catch altseq length: 2100
# Number of variants with reference allele matched with reference genome:
# 1408
# Number of input variants:
# 1408
# Computing 1st file..
# __Processing REF Seqs and ALT Seqs__
# seqslist length : 1408,
# tem_encoded shape : (2816, 4, 2000)
# 2816
# data_all:  (2816, 2000)
# seqslist length : 1408,
# tem_encoded shape : (2816, 4, 2000)
# 2816
# data_all:  (2816, 2000)
# __Predicting__
# 2021-04-29 22:05:39.890684: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:39.892701: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# Q:  Tensor("Embedding-Mapping_1/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_2/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# Q:  Tensor("Transformer-FeedForward-Norm_2/add_1:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# QW:  Tensor("Transformer-MultiHeadSelfAttention_3/dense/BiasAdd:0", shape=(None, None, 256), dtype=float32, device=/replica:0/task:0/device:GPU:0) 8 32
# 2021-04-29 22:05:41.647613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# (2816, 2000)
# 22/22 [==============================] - 3s 121ms/step
#
# Predict epoch:0, y_pred_shape : (2816, 2002)
# 2021-04-29 22:05:44.184040: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:44.185968: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 97ms/step
#
# Predict epoch:1, y_pred_shape : (2816, 2002)
# 2021-04-29 22:05:46.655155: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:46.656512: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 98ms/step
#
# Predict epoch:2, y_pred_shape : (2816, 2002)
# 2021-04-29 22:05:49.167294: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:49.168447: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 105ms/step
#
# Predict epoch:3, y_pred_shape : (2816, 2002)
# 2021-04-29 22:05:51.867842: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:51.868986: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 3s 116ms/step
#
# Predict epoch:4, y_pred_shape : (2816, 2002)
# y_pred_ref shape (2816, 2002)
# 2021-04-29 22:05:54.888364: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:54.889380: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 100ms/step
#
# Predict epoch:0, y_pred_shape : (2816, 2002)
# 2021-04-29 22:05:57.485309: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:05:57.486411: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 99ms/step
#
# Predict epoch:1, y_pred_shape : (2816, 2002)
# 2021-04-29 22:06:00.103697: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:06:00.104806: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 97ms/step
#
# Predict epoch:2, y_pred_shape : (2816, 2002)
# 2021-04-29 22:06:02.693781: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:06:02.694895: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 101ms/step
#
# Predict epoch:3, y_pred_shape : (2816, 2002)
# 2021-04-29 22:06:05.331473: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorFromStringHandle' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorFromStringHandle}}
# 	.  Registered:  device='CPU'
#
# 2021-04-29 22:06:05.336944: W tensorflow/core/grappler/utils/graph_view.cc:830] No registered 'MultiDeviceIteratorGetNextFromShard' OpKernel for GPU devices compatible with node {{node MultiDeviceIteratorGetNextFromShard}}
# 	.  Registered:  device='CPU'
#
# (2816, 2000)
# 22/22 [==============================] - 2s 98ms/step
#
# Predict epoch:4, y_pred_shape : (2816, 2002)
# y_pred_alt shape (2816, 2002)
# logfoldchange and diff array shape : (1408, 4004)
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.ref.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.alt.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.logfoldchange.csv
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.diff.csv
# compute E-values for chromatin effects V2
# /alldata/Nzhang_data/project/T2D/2.background/1.2002mark_5gram/all_bdg_3357_pkl.json
# pkl_filelist length is : 2002
# Pkl finnished : 0
# Pkl finnished : 100
# Pkl finnished : 200
# Pkl finnished : 300
# Pkl finnished : 400
# Pkl finnished : 500
# Pkl finnished : 600
# Pkl finnished : 700
# Pkl finnished : 800
# Pkl finnished : 900
# Pkl finnished : 1000
# Pkl finnished : 1100
# Pkl finnished : 1200
# Pkl finnished : 1300
# Pkl finnished : 1400
# Pkl finnished : 1500
# Pkl finnished : 1600
# Pkl finnished : 1700
# Pkl finnished : 1800
# Pkl finnished : 1900
# Pkl finnished : 2000
# Finished all, writing E-value output file...
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.evalue.csv
# Writing gmean of E-value output file...
# (1408, 1)
# (1408, 6)
# Saving  /alldata/LChuang_data/workspace/Project/GeneBERT/CDTS/1000G_GWAS_1408.vcf_128bs_5gram_2002feature.out.evalue_gmean.csv
